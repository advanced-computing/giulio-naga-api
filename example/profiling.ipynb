# %%
import pandas as pd

df = pd.DataFrame(
    {
        "Category": ["A", "B", "A", "C", "B", "A"],
        "Value": [10, 25, 15, 30, 20, 12],
    }
)
df
# Out:
#   Category  Value
# 0        A     10
# 1        B     25
# 2        A     15
# 3        C     30
# 4        B     20
# 5        A     12

# %% [markdown]
# ## [`describe()`](https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html#summarizing-data-describe)

# %%
df.describe(include="all")
# Out:
#        Category      Value
# count         6   6.000000
# unique        3        NaN
# top           A        NaN
# freq          3        NaN
# mean        NaN  18.666667
# std         NaN   7.788881
# min         NaN  10.000000
# 25%         NaN  12.750000
# 50%         NaN  17.500000
# 75%         NaN  23.750000
# max         NaN  30.000000

# %% [markdown]
# ## [YData Profiling](https://docs.profiling.ydata.ai/latest/)

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# ### Real data
#
# Using [Airbnb data](https://insideairbnb.com/).

# %%
airbnbs = pd.read_csv(
    "https://data.insideairbnb.com/united-states/ny/new-york-city/2025-01-03/data/listings.csv.gz"
)

pd.set_option("display.max_columns", None)
airbnbs
# Out:
#                         id                                       listing_url  \
# 0                    39572                https://www.airbnb.com/rooms/39572
# 1                    39593                https://www.airbnb.com/rooms/39593
# 2                    39704                https://www.airbnb.com/rooms/39704
# 3                    42300                https://www.airbnb.com/rooms/42300
# 4                    42729                https://www.airbnb.com/rooms/42729
# ...                    ...                                               ...
# 37779  1322024128476576885  https://www.airbnb.com/rooms/1322024128476576885
# 37780  1322305006441883773  https://www.airbnb.com/rooms/1322305006441883773
# 37781  1322523395081457963  https://www.airbnb.com/rooms/1322523395081457963
# 37782  1322561224337225530  https://www.airbnb.com/rooms/1322561224337225530
# 37783  1322667742043410903  https://www.airbnb.com/rooms/1322667742043410903
#
#             scrape_id last_scraped           source  \
# 0      20250103033441   2025-01-03      city scrape
# 1      20250103033441   2025-01-03      city scrape
# 2      20250103033441   2025-01-03  previous scrape
# 3      20250103033441   2025-01-03      city scrape
# 4      20250103033441   2025-01-03      city scrape
# ...               ...          ...              ...
# 37779  20250103033441   2025-01-03      city scrape
# 37780  20250103033441   2025-01-03      city scrape
# 37781  20250103033441   2025-01-03      city scrape
# 37782  20250103033441   2025-01-03      city scrape
# 37783  20250103033441   2025-01-03      city scrape
#
#                                                     name  \
# 0                      1 br in a 2 br apt (Midtown West)
# 1                      A lovely room w/ a Manhattan view
# 2                       Private, Large & Sunny 1BR w/W&D
# 3                         Beautiful Lower East Side Loft
# 4      @HouseOnHenrySt - Private 2nd bedroom w/shared...
# ...                                                  ...
# 37779                         The Gem of Riverdale, NYC!
# 37780                                 Amazing 1BR & 1BTH
# 37781  Home Share w/ Young Professionals - 2/3/4/5 Tr...
# 37782      Bedroom for rent in two bedroom UWS apartment
# 37783      Bright room with in-building washer/dryer-394
#
#                                              description  \
# 0                                                    NaN
# 1      A private, furnished  large room to rent Jan/F...
# 2      It's a No Brainer:<br />•Terrific Space For Le...
# 3      Architect-owned loft is a corner unit in a bea...
# 4                                                    NaN
# ...                                                  ...
# 37779  Visiting NYC and looking for a place to stay? ...
# 37780  This special place is close to everything, mak...
# 37781  Sun-filled, fully furnished apartment located ...
# 37782  bedroom available for short and long-term rent...
# 37783  Bedford Avenue #394<br />- Bright bedroom with...
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 1      Nate Silver called this super safe, clean, qui...
# 2      The Neighborhood<br />• Rich History <br />• B...
# 3      The apartment is in the border of Soho, LES an...
# 4      Lovely old Brooklyn neighborhood, with brick/b...
# ...                                                  ...
# 37779                                                NaN
# 37780                                                NaN
# 37781                                                NaN
# 37782                                                NaN
# 37783                                                NaN
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/fd1bffd9-ccf8...     169927
# 1      https://a0.muscache.com/pictures/0b9110f7-3b24...     110506
# 2      https://a0.muscache.com/pictures/0bc4e8a4-c047...     170510
# 3      https://a0.muscache.com/pictures/0e285e13-ee14...     184755
# 4      https://a0.muscache.com/pictures/925fe213-f5e1...      11481
# ...                                                  ...        ...
# 37779  https://a0.muscache.com/pictures/hosting/Hosti...   35391290
# 37780  https://a0.muscache.com/pictures/miso/Hosting-...  504878421
# 37781  https://a0.muscache.com/pictures/miso/Hosting-...    2822805
# 37782  https://a0.muscache.com/pictures/hosting/Hosti...  666385153
# 37783  https://a0.muscache.com/pictures/miso/Hosting-...   41475188
#
#                                           host_url        host_name  \
# 0         https://www.airbnb.com/users/show/169927           Hubert
# 1         https://www.airbnb.com/users/show/110506            Myung
# 2         https://www.airbnb.com/users/show/170510            Renée
# 3         https://www.airbnb.com/users/show/184755            Koray
# 4          https://www.airbnb.com/users/show/11481          Annette
# ...                                            ...              ...
# 37779   https://www.airbnb.com/users/show/35391290            Oscar
# 37780  https://www.airbnb.com/users/show/504878421            Karan
# 37781    https://www.airbnb.com/users/show/2822805          Olivier
# 37782  https://www.airbnb.com/users/show/666385153  Kiana Elizabeth
# 37783   https://www.airbnb.com/users/show/41475188          Tatiana
#
#        host_since                 host_location  \
# 0      2010-07-17  Saint-Aubin-sur-Scie, France
# 1      2010-04-18                  New York, NY
# 2      2010-07-18       New York, United States
# 3      2010-07-29                  New York, NY
# 4      2009-03-26                  New York, NY
# ...           ...                           ...
# 37779  2015-06-09                  New York, NY
# 37780  2023-03-11                  New York, NY
# 37781  2012-07-03                  New York, NY
# 37782  2024-12-10                           NaN
# 37783  2015-08-14                  New York, NY
#
#                                               host_about  host_response_time  \
# 0      Facebook Likes:\r\nNew York French Geek, David...        within a day
# 1      I grew up in South Korea, moved to Montreal, C...  within a few hours
# 2      I am a self employed licensed real estate brok...                 NaN
# 3      I am an architect living in NYC and have my ow...        within a day
# 4      I have been a host with Airbnb since its intro...        within a day
# ...                                                  ...                 ...
# 37779                    outgoing , positive and happy\n        within a day
# 37780                                                NaN  within a few hours
# 37781  I'm Ollie, a creative professional based in NY...      within an hour
# 37782                                                NaN                 NaN
# 37783            Love skiing, ocean, traveling the world  within a few hours
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 0                   100%                  NaN                 f
# 1                   100%                  60%                 f
# 2                    NaN                  NaN                 f
# 3                   100%                 100%                 f
# 4                    67%                  33%                 f
# ...                  ...                  ...               ...
# 37779                50%                 100%                 f
# 37780               100%                 100%                 f
# 37781                98%                  71%                 t
# 37782                NaN                  NaN                 f
# 37783                95%                  49%                 f
#
#                                       host_thumbnail_url  \
# 0      https://a0.muscache.com/im/users/169927/profil...
# 1      https://a0.muscache.com/im/pictures/user/bba06...
# 2      https://a0.muscache.com/im/pictures/user/a6f6d...
# 3      https://a0.muscache.com/im/users/184755/profil...
# 4      https://a0.muscache.com/im/users/11481/profile...
# ...                                                  ...
# 37779  https://a0.muscache.com/im/pictures/user/019ca...
# 37780  https://a0.muscache.com/im/pictures/user/User-...
# 37781  https://a0.muscache.com/im/pictures/user/313dd...
# 37782  https://a0.muscache.com/im/pictures/user/5b586...
# 37783  https://a0.muscache.com/im/pictures/user/User-...
#
#                                         host_picture_url  host_neighbourhood  \
# 0      https://a0.muscache.com/im/users/169927/profil...      Hell's Kitchen
# 1      https://a0.muscache.com/im/pictures/user/bba06...           Sunnyside
# 2      https://a0.muscache.com/im/pictures/user/a6f6d...  Bedford-Stuyvesant
# 3      https://a0.muscache.com/im/users/184755/profil...     Lower East Side
# 4      https://a0.muscache.com/im/users/11481/profile...     Carroll Gardens
# ...                                                  ...                 ...
# 37779  https://a0.muscache.com/im/pictures/user/019ca...          West Bronx
# 37780  https://a0.muscache.com/im/pictures/user/User-...                 NaN
# 37781  https://a0.muscache.com/im/pictures/user/313dd...  Bedford-Stuyvesant
# 37782  https://a0.muscache.com/im/pictures/user/5b586...                 NaN
# 37783  https://a0.muscache.com/im/pictures/user/User-...           Southside
#
#        host_listings_count  host_total_listings_count  \
# 0                      2.0                        2.0
# 1                      1.0                        1.0
# 2                      2.0                        4.0
# 3                      1.0                        1.0
# 4                      6.0                       12.0
# ...                    ...                        ...
# 37779                  3.0                        3.0
# 37780                  4.0                        5.0
# 37781                 24.0                       28.0
# 37782                  1.0                        1.0
# 37783                 16.0                       46.0
#
#                      host_verifications host_has_profile_pic  \
# 0                    ['email', 'phone']                    t
# 1                    ['email', 'phone']                    t
# 2      ['email', 'phone', 'work_email']                    t
# 3      ['email', 'phone', 'work_email']                    t
# 4                    ['email', 'phone']                    t
# ...                                 ...                  ...
# 37779  ['email', 'phone', 'work_email']                    t
# 37780                ['email', 'phone']                    t
# 37781                ['email', 'phone']                    t
# 37782                ['email', 'phone']                    t
# 37783                ['email', 'phone']                    t
#
#       host_identity_verified            neighbourhood neighbourhood_cleansed  \
# 0                          t                      NaN         Hell's Kitchen
# 1                          t  Neighborhood highlights              Sunnyside
# 2                          t  Neighborhood highlights     Bedford-Stuyvesant
# 3                          t  Neighborhood highlights        Lower East Side
# 4                          t  Neighborhood highlights        Carroll Gardens
# ...                      ...                      ...                    ...
# 37779                      t                      NaN            Kingsbridge
# 37780                      t                      NaN     Financial District
# 37781                      t                      NaN          Crown Heights
# 37782                      t                      NaN        Upper West Side
# 37783                      t                      NaN          Crown Heights
#
#       neighbourhood_group_cleansed  latitude  longitude  \
# 0                        Manhattan  40.76203  -73.98869
# 1                           Queens  40.74523  -73.92318
# 2                         Brooklyn  40.68216  -73.94594
# 3                        Manhattan  40.71992  -73.99167
# 4                         Brooklyn  40.67813  -74.00062
# ...                            ...       ...        ...
# 37779                        Bronx  40.88178  -73.89973
# 37780                    Manhattan  40.70610  -74.00666
# 37781                     Brooklyn  40.67013  -73.95874
# 37782                    Manhattan  40.79655  -73.97462
# 37783                     Brooklyn  40.67469  -73.95346
#
#                      property_type        room_type  accommodates  bathrooms  \
# 0      Private room in rental unit     Private room             2        NaN
# 1            Private room in condo     Private room             1        1.0
# 2                 Entire townhouse  Entire home/apt             4        NaN
# 3                      Entire loft  Entire home/apt             5        2.0
# 4        Private room in townhouse     Private room             2        1.0
# ...                            ...              ...           ...        ...
# 37779                 Entire place  Entire home/apt             2        1.0
# 37780           Entire rental unit  Entire home/apt             2        1.0
# 37781  Private room in rental unit     Private room             2        2.0
# 37782  Private room in rental unit     Private room             1        1.0
# 37783  Private room in rental unit     Private room             1        2.0
#
#        bathrooms_text  bedrooms  beds  \
# 0                 NaN       1.0   1.0
# 1      1 private bath       1.0   1.0
# 2              1 bath       1.0   NaN
# 3             2 baths       3.0   4.0
# 4      1 private bath       1.0   1.0
# ...               ...       ...   ...
# 37779          1 bath       1.0   1.0
# 37780          1 bath       1.0   1.0
# 37781  2 shared baths       1.0   1.0
# 37782   1 shared bath       1.0   1.0
# 37783  2 shared baths       5.0   1.0
#
#                                                amenities    price  \
# 0      ["Hangers", "Wifi", "Smoke alarm", "Carbon mon...  $139.00
# 1      ["Hangers", "Smoke alarm", "Hair dryer", "Clot...   $78.00
# 2      ["Hangers", "Coffee maker", "Smoke alarm", "Fi...      NaN
# 3      ["Hangers", "Coffee maker", "Smoke alarm", "Ha...  $750.00
# 4      ["Hangers", "Coffee maker", "Smoke alarm", "TV...  $185.00
# ...                                                  ...      ...
# 37779  ["Hangers", "Smoke alarm", "Fire extinguisher"...  $159.00
# 37780  ["Dedicated workspace", "HDTV with Amazon Prim...  $199.00
# 37781  ["Hangers", "Smoke alarm", "Stove", "Cooking b...   $99.00
# 37782  ["Wifi", "Central air conditioning", "Hot wate...  $131.00
# 37783  ["Wifi", "TV", "Dedicated workspace", "Carbon ...   $47.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0                  30            1125                    30.0
# 1                  31             150                    31.0
# 2                  30              30                    30.0
# 3                  30             240                    30.0
# 4                  30              60                    30.0
# ...               ...             ...                     ...
# 37779              30             365                    30.0
# 37780              30             365                    30.0
# 37781              30             365                    30.0
# 37782              30              90                    30.0
# 37783              30             365                    30.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                        30.0                  1125.0                  1125.0
# 1                        31.0                   150.0                   150.0
# 2                        30.0                    30.0                    30.0
# 3                        30.0                   240.0                   240.0
# 4                        30.0                    60.0                    60.0
# ...                       ...                     ...                     ...
# 37779                    30.0                   365.0                   365.0
# 37780                    30.0                   365.0                   365.0
# 37781                  1000.0                   365.0                  1000.0
# 37782                    30.0                    90.0                    90.0
# 37783                    30.0                   365.0                   365.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                        30.0                  1125.0               NaN
# 1                        31.0                   150.0               NaN
# 2                        30.0                    30.0               NaN
# 3                        30.0                   240.0               NaN
# 4                        30.0                    60.0               NaN
# ...                       ...                     ...               ...
# 37779                    30.0                   365.0               NaN
# 37780                    30.0                   365.0               NaN
# 37781                   190.6                   470.1               NaN
# 37782                    30.0                    90.0               NaN
# 37783                    30.0                   365.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 0                    t               30               60               90
# 1                    t                0                0                0
# 2                    t                0                0                0
# 3                    t                0                0                0
# 4                    t               29               59               89
# ...                ...              ...              ...              ...
# 37779                t               30               60               90
# 37780                t               29               29               31
# 37781                t               18               48               65
# 37782                t               23               53               83
# 37783                t                1               31               61
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 0                   365            2025-01-03                 44
# 1                   248            2025-01-03                 34
# 2                     0            2025-01-03                337
# 3                    87            2025-01-03                 70
# 4                   364            2025-01-03                220
# ...                 ...                   ...                ...
# 37779               365            2025-01-03                  0
# 37780               306            2025-01-03                  0
# 37781                65            2025-01-03                  0
# 37782                83            2025-01-03                  0
# 37783               336            2025-01-03                  0
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                          0                       0   2010-08-31  2019-01-03
# 1                          1                       0   2010-09-14  2024-08-05
# 2                          0                       0   2010-08-23  2019-12-12
# 3                          1                       0   2010-08-08  2024-08-31
# 4                          0                       0   2010-09-13  2023-11-02
# ...                      ...                     ...          ...         ...
# 37779                      0                       0          NaN         NaN
# 37780                      0                       0          NaN         NaN
# 37781                      0                       0          NaN         NaN
# 37782                      0                       0          NaN         NaN
# 37783                      0                       0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      4.86                    4.93
# 1                      4.93                    4.89
# 2                      4.71                    4.86
# 3                      4.80                    4.72
# 4                      4.66                    4.78
# ...                     ...                     ...
# 37779                   NaN                     NaN
# 37780                   NaN                     NaN
# 37781                   NaN                     NaN
# 37782                   NaN                     NaN
# 37783                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.83                   4.98
# 1                           4.89                   4.96
# 2                           4.82                   4.89
# 3                           4.69                   4.85
# 4                           4.81                   4.71
# ...                          ...                    ...
# 37779                        NaN                    NaN
# 37780                        NaN                    NaN
# 37781                        NaN                    NaN
# 37782                        NaN                    NaN
# 37783                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 0                             5.00                    4.98
# 1                             4.96                    4.79
# 2                             4.92                    4.38
# 3                             4.87                    4.57
# 4                             4.73                    4.58
# ...                            ...                     ...
# 37779                          NaN                     NaN
# 37780                          NaN                     NaN
# 37781                          NaN                     NaN
# 37782                          NaN                     NaN
# 37783                          NaN                     NaN
#
#        review_scores_value license instant_bookable  \
# 0                     4.86     NaN                f
# 1                     4.93     NaN                f
# 2                     4.72     NaN                f
# 3                     4.62     NaN                f
# 4                     4.64     NaN                f
# ...                    ...     ...              ...
# 37779                  NaN     NaN                f
# 37780                  NaN     NaN                f
# 37781                  NaN     NaN                f
# 37782                  NaN     NaN                f
# 37783                  NaN     NaN                f
#
#        calculated_host_listings_count  \
# 0                                   2
# 1                                   1
# 2                                   2
# 3                                   1
# 4                                   4
# ...                               ...
# 37779                               3
# 37780                               3
# 37781                              21
# 37782                               1
# 37783                              13
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                1
# 1                                                0
# 2                                                2
# 3                                                1
# 4                                                1
# ...                                            ...
# 37779                                            3
# 37780                                            3
# 37781                                            0
# 37782                                            0
# 37783                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 1
# 1                                                 1
# 2                                                 0
# 3                                                 0
# 4                                                 3
# ...                                             ...
# 37779                                             0
# 37780                                             0
# 37781                                            21
# 37782                                             1
# 37783                                            13
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                                0               0.25
# 1                                                0               0.20
# 2                                                0               1.93
# 3                                                0               0.40
# 4                                                0               1.26
# ...                                            ...                ...
# 37779                                            0                NaN
# 37780                                            0                NaN
# 37781                                            0                NaN
# 37782                                            0                NaN
# 37783                                            0                NaN
#
# [37784 rows x 75 columns]

# %%
airbnbs["price"]
# Out:
# 0        $139.00
# 1         $78.00
# 2            NaN
# 3        $750.00
# 4        $185.00
#           ...
# 37779    $159.00
# 37780    $199.00
# 37781     $99.00
# 37782    $131.00
# 37783     $47.00
# Name: price, Length: 37784, dtype: object

# %%
airbnbs["price"] = (
    airbnbs["price"].str.replace("$", "").str.replace(",", "").astype(float)
)
airbnbs["price"]
# Out:
# 0        139.0
# 1         78.0
# 2          NaN
# 3        750.0
# 4        185.0
#          ...
# 37779    159.0
# 37780    199.0
# 37781     99.0
# 37782    131.0
# 37783     47.0
# Name: price, Length: 37784, dtype: float64

# %% [markdown]
# The following needs to be re-run each time the notebook is opened to render properly.

# %%
airbnbs_minimal = airbnbs[["id", "name", "price", "beds", "neighbourhood_cleansed"]]

profile = ProfileReport(
    airbnbs_minimal,
    title="Airbnb Listings Report",
    # https://docs.profiling.ydata.ai/latest/advanced_settings/available_settings/#setting-dataset-schema-type
    type_schema={
        "neighbourhood_cleansed": "categorical",
    },
)

# speed this up
# https://docs.profiling.ydata.ai/latest/features/big_data/#disable-expensive-computations
profile.config.interactions.targets = ["price", "beds", "neighbourhood_cleansed"]

profile.to_widgets()
# Out:
# /Users/afeld/dev/advanced-computing/course-materials/.venv/lib/python3.12/site-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
from profiling_helpers import parse_dollars

parse_dollars(airbnbs["price"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 from profiling_helpers import parse_dollars
# ----> 3 parse_dollars(airbnbs["price"])
#
# File ~/dev/advanced-computing/course-materials/examples/profiling/profiling_helpers.py:5, in parse_dollars(amounts)
#       4 def parse_dollars(amounts: pd.Series):
# ----> 5     return amounts.str.replace("$", "").str.replace(",", "").astype(float)
#
# File ~/dev/advanced-computing/course-materials/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~/dev/advanced-computing/course-materials/.venv/lib/python3.12/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/dev/advanced-computing/course-materials/.venv/lib/python3.12/site-packages/pandas/core/strings/accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/dev/advanced-computing/course-materials/.venv/lib/python3.12/site-packages/pandas/core/strings/accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!
