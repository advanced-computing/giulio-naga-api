# %%
import pandas as pd

df = pd.read_csv('energy.csv')
df
# Out:
#                   Company Name  Total Interns  Employees  \
# 0      1366 Technologies, Inc.             10       55.0
# 1              180 South Solar              1        4.0
# 2       24M Technologies, Inc.             34      148.0
# 3       2Witech Solutions, LLC              4        3.0
# 4            360Chestnut, Inc.             22        6.0
# ..                         ...            ...        ...
# 774  Zephyr Energy Corporation              1        1.0
# 775   Zephyr Innovations, Inc.              2        2.0
# 776    ZERO (Gunnison Company)              2        1.0
# 777          ZeroEnergy Design             21        8.0
# 778            ZwitterCo, Inc.             10       35.0
#
#                            Address        Town State   Zip             Sector
# 0                     6 Preston Ct     Bedford    MA  1730              Solar
# 1    2 Merrimack Street, 3rd Floor   Haverhill    MA  1830              Solar
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
profile.to_widgets()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 4
#       1 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
# ----> 4 profile.to_widgets()
#
# File ~/Data Analysis/Advanced Computing for Policy/giulio-naga-api/.venv/lib/python3.12/site-packages/ydata_profiling/profile_report.py:535, in ProfileReport.to_widgets(self)
#     532 except ModuleNotFoundError:
#     533     pass
# --> 535 from IPython.core.display import display
#     537 display(self.widgets)
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (/Users/NGSWTKAK/Data Analysis/Advanced Computing for Policy/giulio-naga-api/.venv/lib/python3.12/site-packages/IPython/core/display.py)

# %%
def check_numeric(data, column):
    assert data[column].dtype in ['int64', 'float64'], f'{column} is not numeric'

numeric_cols = ['Total Interns', 'Employees']

for col in numeric_cols:
    check_numeric(df, col)

print("all the columns are numeric.")
# Out:
# all the columns are numeric.

# %%
def is_outlier(value, q1, q3):
    iqr = q3 - q1
    lower_bound = q1 - 1.5*iqr
    upper_bound = q3 + 1.5*iqr
    return value < lower_bound or value > upper_bound

def column_has_outliers(data, column):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    return data[column].apply(lambda x: is_outlier(x, q1, q3))

assert not column_has_outliers(df, 'Total Interns').any(), 'Total Interns has outliers'
assert not column_has_outliers(df, 'Employees').any(), 'Employees has outliers'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 12
#       9     q3 = data[column].quantile(0.75)
#      10     return data[column].apply(lambda x: is_outlier(x, q1, q3))
# ---> 12 assert not column_has_outliers(df, 'Total Interns').any(), 'Total Interns has outliers'
#      13 assert not column_has_outliers(df, 'Employees').any(), 'Employees has outliers'
#
# AssertionError: Total Interns has outliers
